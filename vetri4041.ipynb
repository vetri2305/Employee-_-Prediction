# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-96ffef63-47c2-481d-8b63-e280d6451c4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96ffef63-47c2-481d-8b63-e280d6451c4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Employe_Data.csv')

# %%
df.head(6)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.37             0.52               2                   159
# 2                0.41             0.50               2                   153
# 3                0.42             0.53               2                   142
# 4                0.45             0.54               2                   135
# 5                0.41             0.55               2                   148
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   3              0     1                      0
# 2                   3              0     1                      0
# 3                   3              0     1                      0
# 4                   3              0     1                      0
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments ', 'Grade', 'salary', 'increment',
#        'experience', 'Attrition'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1584 entries, 0 to 1583
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     1584 non-null   float64
#  1   last_evaluation        1584 non-null   float64
#  2   number_project         1584 non-null   int64
#  3   average_montly_hours   1584 non-null   int64
#  4   time_spend_company     1584 non-null   int64
#  5   Work_accident          1584 non-null   int64
#  6   left                   1584 non-null   int64
#  7   promotion_last_5years  1584 non-null   int64
#  8   Departments            1584 non-null   object
#  9   Grade                  1584 non-null   object
#  10  salary                 1584 non-null   object
#  11  increment              1584 non-null   object
#  12  experience             1584 non-null   int64
#  13  Attrition              1584 non-null   object
# dtypes: float64(2), int64(7), object(5)
# ...

# %%
df.shape
# Out:
# (1584, 14)

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Departments              0
# Grade                    0
# salary                   0
# increment                0
# experience               0
# Attrition                0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1579    False
# 1580    False
# 1581    False
# 1582    False
# 1583    False
# Length: 1584, dtype: bool

# %%
for column in df.columns:
    print("{}:{}".format(column,df[column].nunique()))
# Out:
# satisfaction_level:77
# last_evaluation:52
# number_project:6
# average_montly_hours:156
# time_spend_company:5
# Work_accident:2
# left:1
# promotion_last_5years:2
# Departments :10
# Grade:6
# salary:3
# increment:10
# experience:11
# Attrition:2

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count         1584.000000      1584.000000     1584.000000
# mean             0.442146         0.722153        3.875631
# std              0.265075         0.197197        1.807631
# min              0.090000         0.450000        2.000000
# 25%              0.120000         0.520000        2.000000
# 50%              0.410000         0.790000        4.000000
# 75%              0.730000         0.900000        6.000000
# max              0.920000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident    left  \
# count            1584.00000         1584.000000    1584.000000  1584.0
# mean              208.40404            3.878788       0.052399     1.0
# std                61.54802            0.973667       0.222901     0.0
# min               126.00000            2.000000       0.000000     1.0
# 25%               146.00000            3.000000       0.000000     1.0
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
#            yes      1045
#               no     539
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Attrition'])
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
numeric_col=list(df.select_dtypes(include=np.number).columns)
categorical_col=list(df.select_dtypes(include=object).columns)

# %%
for col in numeric_col:
    sns.histplot(x=df[col])
    plt.show()

# %%
df.groupby('experience')['Attrition'].value_counts(normalize=True)
# Out:
# experience  Attrition
# 2                      yes      0.663717
#                           no    0.336283
# 3                      yes      0.663717
#                           no    0.336283
# 4                      yes      0.696429
#                           no    0.303571
# 5                      yes      0.668142
#                           no    0.331858
# 6                      yes      0.663717
#                           no    0.336283
# 7                      yes      0.654867
#                           no    0.345133
# 8                      yes      0.663717
#                           no    0.336283
# 9                      yes      0.649123
#                           no    0.350877
# 10                     yes      0.649123
#                           no    0.350877
# 11                     yes      0.647577
#                           no    0.352423
# 12                     yes      0.646018
#                           no    0.353982
# ...

# %%
x=df.loc[:,df.columns!='Attrition']
y=df['Attrition']

# %%
x
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 0                   0.38             0.53               2
# 1                   0.37             0.52               2
# 2                   0.41             0.50               2
# 3                   0.42             0.53               2
# 4                   0.45             0.54               2
# ...                  ...              ...             ...
# 1579                0.10             0.85               7
# 1580                0.10             0.82               7
# 1581                0.09             0.84               7
# 1582                0.09             0.87               7
# 1583                0.10             0.86               7
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 0                      157                   3              0     1
# 1                      159                   3              0     1
# ...

# %%
y
# Out:
# 0                   yes
# 1                   yes
# 2                   yes
# 3                   yes
# 4                   yes
#               ...
# 1579                  no
# 1580                  no
# 1581                  no
# 1582                  no
# 1583                  no
# Name: Attrition, Length: 1584, dtype: object
